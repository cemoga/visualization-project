# %% [markdown]
# # Census Data Query

# %% [markdown]
# ### Calling necesary dependencies

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests


# Dependencies to consult tables from the Census
import json
import pprint
import requests

# Census API Keys
from config import (api_key)

# %% [markdown]
# ### Exploring the data

# %%
base_url = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?api_key='

query_url = base_url + api_key + "&school.zip=08873"

response = requests.get(query_url).json()
# Alternative way of printing the json response
# print(json.dumps(response, indent=4, sort_keys=True))
print(query_url)
pprint.pprint(response)
# Out:
# https://api.data.gov/ed/collegescorecard/v1/schools.json?api_key=RvkoJNg6NjLAKGyILO4JSqNsvaiOWEOmFxhoemNt&school.zip=08873
# {'metadata': {'page': 0, 'per_page': 20, 'total': 1},
#  'results': [{'2016': {'programs': {'cip_4_digit': [{'code': '5106',
#                                                      'counts': {'ipeds_awards1': None,
#                                                                 'ipeds_awards2': 0,
#                                                                 'titleiv': 143},
#                                                      'credential': {'level': 1,
#                                                                     'title': 'Undergraduate '
#                                                                              'Certificate '
#                                                                              'or '
#                                                                              'Diploma'},
# ...

# %%
response["results"][0]["2016"]
# Out:
# {'programs': {'cip_4_digit': [{'earnings': {'median_earnings': 22900,
#      'count': 133},
#     'ope6_id': '021066',
#     'code': '5106',
#     'credential': {'level': 1,
#      'title': 'Undergraduate Certificate or Diploma'},
#     'school': {'main_campus': '0',
#      'name': 'American Institute-Somerset',
#      'type': 'Private, for-profit'},
#     'counts': {'titleiv': 143, 'ipeds_awards2': 0, 'ipeds_awards1': None},
#     'title': 'Dental Support Services and Allied Professions.',
#     'debt': {'median_debt': 11795,
#      'count': 162,
#      'mean_debt': 12148,
#      'monthly_debt_payment': 122},
#     'unit_id': '490869'},
#    {'earnings': {'median_earnings': 20000, 'count': 449},
#     'ope6_id': '021066',
#     'code': '5108',
#     'credential': {'level': 1,
#      'title': 'Undergraduate Certificate or Diploma'},
#     'school': {'main_campus': '0',
#      'name': 'American Institute-Somerset',
#      'type': 'Private, for-profit'},
# ...
