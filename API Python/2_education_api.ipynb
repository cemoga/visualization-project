# %% [markdown]
# # Education API Query

# %% [markdown]
# ### Calling necesary dependencies

# %%
# Dependencies
import pandas as pd
import numpy as np
import requests


# Dependencies to consult tables from the API
import json
import pprint
import requests

# Census API Keys
from config import (api_key)

# %% [markdown]
# ### Exploring the data

# %%
base_url = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?api_key='

# query_url = base_url + api_key  + "&school.state=NY"
# query_url = base_url + api_key  + "&school.zip=08873"

rest_1 = "&fields=school.open_admissions_policy,school.ownership_peps,school.price_calculator_url,school.city,school.ft_faculty_rate,school.locale,school.accreditor,school.main_campus,school.alias,school.faculty_salary,school.state,school.operating,school.instructional_expenditure_per_fte,school.state_fips,school.zip,school.carnegie_undergrad,school.women_only,school.religious_affiliation,school.tuition_revenue_per_fte,school.under_investigation,school.region_id,school.carnegie_basic,school.branches,school.men_only,school.school_url,school.online_only,school.ownership,school.accreditor_code,school.name,school.degree_urbanization,school.carnegie_size_setting,school.degrees_awarded.predominant,school.degrees_awarded.highest,school.institutional_characteristics.level,school.title_iv.approval_date,school.title_iv.eligibility_type,id,ope8_id,ope6_id,location.lon,location.lat,2017.cost.tuition.in_state,2017.cost.tuition.out_of_state,"

rest_2 = "&per_page=100"

query_url = base_url + api_key + rest_1 + rest_2
response = requests.get(query_url).json()
# Alternative way of printing the json response
# print(json.dumps(response, indent=4, sort_keys=True))
print(query_url)
# pprint.pprint(response)
print(response)
# Out:
# https://api.data.gov/ed/collegescorecard/v1/schools.json?api_key=RvkoJNg6NjLAKGyILO4JSqNsvaiOWEOmFxhoemNt&fields=school.open_admissions_policy,school.ownership_peps,school.price_calculator_url,school.city,school.ft_faculty_rate,school.locale,school.accreditor,school.main_campus,school.alias,school.faculty_salary,school.state,school.operating,school.instructional_expenditure_per_fte,school.state_fips,school.zip,school.carnegie_undergrad,school.women_only,school.religious_affiliation,school.tuition_revenue_per_fte,school.under_investigation,school.region_id,school.carnegie_basic,school.branches,school.men_only,school.school_url,school.online_only,school.ownership,school.accreditor_code,school.name,school.degree_urbanization,school.carnegie_size_setting,school.degrees_awarded.predominant,school.degrees_awarded.highest,school.institutional_characteristics.level,school.title_iv.approval_date,school.title_iv.eligibility_type,id,ope8_id,ope6_id,location.lon,location.lat,2017.cost.tuition.in_state,2017.cost.tuition.out_of_state,&per_page=100
# {'metadata': {'total': 7112, 'page': 0, 'per_page': 100}, 'results': [{'school.women_only': 0, 'school.tuition_revenue_per_fte': 5920, 'school.main_campus': 1, 'school.title_iv.eligibility_type': 1, 'school.title_iv.approval_date': '12/12/1986', 'school.city': 'Kalamazoo', 'school.branches': 1, 'school.men_only': 0, 'school.degrees_awarded.highest': 1, 'school.institutional_characteristics.level': 2, 'school.carnegie_basic': -2, 'school.zip': '49008', 'location.lat': 42.259329, 'school.state': 'MI', 'id': 152044, 'school.under_investigation': 0, 'school.operating': 1, 'school.instructional_expenditure_per_fte': 1628, 'school.carnegie_size_setting': -2, 'school.region_id': 3, 'location.lon': -85.590244, 'school.accreditor_code': 'NACCAS', 'school.accreditor': 'National Accrediting Commission of Career Arts and Sciences', 'school.name': 'West Michigan College of Barbering and Beauty', 'school.state_fips': 26, 'school.ownership_peps': 3, 'school.ownership': 3, 'ope6_id': '024910', 'school.price_calculator_url': 'westmichigancollegeofbarberingandbeauty.com', 'school.school_url': 'westmichigancollegeofbarberingandbeauty.com', 'school.carnegie_undergrad': -2, 'school.degrees_awarded.predominant': 1, 'ope8_id': '02491000', 'school.open_admissions_policy': 1, 'school.locale': 13, 'school.online_only': 0, 'school.ft_faculty_rate': None, 'school.alias': None, 'school.faculty_salary': None, 'school.religious_affiliation': None, 'school.degree_urbanization': None, '2017.cost.tuition.in_state': None, '2017.cost.tuition.out_of_state': None}, {'school.women_only': 0, '2017.cost.tuition.in_state': 9346, 'school.tuition_revenue_per_fte': 8545, 'school.main_campus': 1, 'school.title_iv.eligibility_type': 1, 'school.title_iv.approval_date': '12/1/1965', 'school.city': 'Milledgeville', 'school.branches': 1, 'school.men_only': 0, 'school.degrees_awarded.highest': 4, 'school.institutional_characteristics.level': 1, 'school.carnegie_basic': 18, 'school.zip': '31061', 'location.lat': 33.082787, 'school.alias': 'Georgia College', 'school.state': 'GA', 'id': 139861, 'school.under_investigation': 0, 'school.operating': 1, 'school.instructional_expenditure_per_fte': 6478, 'school.carnegie_size_setting': 13, 'school.region_id': 5, 'location.lon': -83.231962, 'school.accreditor_code': 'SACSCC', 'school.accreditor': 'Southern Association of Colleges and Schools Commission on Colleges', 'school.name': 'Georgia College & State University', 'school.state_fips': 13, 'school.ft_faculty_rate': 0.8416, 'school.ownership_peps': 1, 'school.ownership': 1, 'ope6_id': '001602', 'school.price_calculator_url': 'irout.gcsu.edu/cc/', 'school.school_url': 'www.gcsu.edu/', '2017.cost.tuition.out_of_state': 28060, 'school.carnegie_undergrad': 14, 'school.degrees_awarded.predominant': 3, 'ope8_id': '00160200', 'school.open_admissions_policy': 2, 'school.locale': 32, 'school.faculty_salary': 6958, 'school.online_only': 0, 'school.religious_affiliation': None, 'school.degree_urbanization': None}, {'school.women_only': 0, '2017.cost.tuition.in_state': 6356, 'school.tuition_revenue_per_fte': 6087, 'school.main_campus': 1, 'school.title_iv.eligibility_type': 1, 'school.title_iv.approval_date': '12/1/1965', 'school.city': 'Statesboro', 'school.branches': 1, 'school.men_only': 0, 'school.degrees_awarded.highest': 4, 'school.institutional_characteristics.level': 1, 'school.carnegie_basic': 16, 'school.zip': '30460-8126', 'location.lat': 32.426153, 'school.state': 'GA', 'id': 139931, 'school.under_investigation': 0, 'school.operating': 1, 'school.instructional_expenditure_per_fte': 6408, 'school.carnegie_size_setting': 16, 'school.region_id': 5, 'location.lon': -81.784045, 'school.accreditor_code': 'SACSCC', 'school.accreditor': 'Southern Association of Colleges and Schools Commission on Colleges', 'school.name': 'Georgia Southern University', 'school.state_fips': 13, 'school.ft_faculty_rate': 0.9026, 'school.ownership_peps': 1, 'school.ownership': 1, 'ope6_id': '001572', 'school.price ...

# %%
school_data = response["results"]
school_data[1]['school.open_admissions_policy']
# Out:
# 2

# %% [markdown]
# ## Initial Dataframe Creation

# %%
# Store the Json response to a varible
school_data = response["results"]
# Initialize the dataframe containing all the fields
school_data_df = pd.DataFrame(columns = ['open_admissions_policy', 'ownership_peps', 
                                         'price_calculator_url', 'city', 'ft_faculty_rate', 
                                         'locale', 'accreditor', 'main_campus', 'alias', 
                                         'faculty_salary', 'state', 'operating', 
                                         'instructional_expenditure_per_fte', 
                                         'state_fips', 'zip', 'carnegie_undergrad', 
                                         'women_only', 'religious_affiliation', 
                                         'tuition_revenue_per_fte', 'under_investigation', 
                                         'region_id', 'carnegie_basic', 'branches', 'men_only', 
                                         'school_url', 'online_only', 'ownership', 'accreditor_code', 
                                         'name', 'degree_urbanization', 'carnegie_size_setting', 
                                         'degrees_awarded_predominant', 'degrees_awarded_highest', 
                                         'institutional_characteristics_level', 'title_iv_approval_date', 
                                         'title_iv_eligibility_type', 'id', 'ope8_id', 'ope6_id',
                                         'location_lon', 'location_lat' 'tuition_in_state', 
                                         'tuition_out_of_state'])

# Create all the lists to store the individual queries
school_open_admissions_policy = [] # Open admissions policy indicator
school_ownership_peps = [] # Control of institution, per PEPS
school_price_calculator_url = [] # URL for institution's net price calculator
school_city = [] # City
school_ft_faculty_rate = [] # Proportion of faculty that is full-time
school_locale = [] # Locale of institution
school_accreditor = [] # Accreditor for institution
school_main_campus = [] # Flag for main campus
school_alias = [] # Institution name aliases
school_faculty_salary = [] # Average faculty salary
school_state = [] # State postcode
school_operating = [] # Flag for currently operating institution, 0=closed, 1=operating
school_instructional_expenditure_per_fte = [] # Instructional expenditures per full-time equivalent student
school_state_fips = [] # FIPS code for state
school_zip = [] # ZIP code
school_carnegie_undergrad = [] # Carnegie Classification -- undergraduate profile
school_women_only = [] # Flag for women-only college
school_religious_affiliation = [] # Religous affiliation of the institution
school_tuition_revenue_per_fte = [] # Net tuition revenue per full-time equivalent student
school_under_investigation = [] # Schools that are on Heightened Cash Monitoring 2 by the Department of Education
school_region_id = [] # Region (IPEDS)
school_carnegie_basic = [] # Carnegie Classification -- basic
school_branches = [] # Number of branch campuses
school_men_only = [] # Flag for men-only college
school_school_url = [] # URL for institution's homepage
school_online_only = [] # Flag for distance-education-only education
school_ownership = [] # Control of institution
school_accreditor_code = [] # Code corresponding to accreditor (as captured from PEPS)
school_name = [] # Institution name
school_degree_urbanization = [] # Degree of urbanization of institution
school_carnegie_size_setting = [] # Carnegie Classification -- size and setting

school_degrees_awarded_predominant = [] # Predominant undergraduate degree awarded
school_degrees_awarded_highest = [] # Highest degree awarded
school_institutional_characteristics_level = [] # Level of institution
school_title_iv_approval_date = [] # Date that institution was first approved to participate in Title IV aid programs
school_title_iv_eligibility_type = [] # Title IV eligibility type

school_id = [] # Unit ID for institution
school_ope8_id = [] # 8-digit OPE ID for institution
school_ope6_id = [] # 6-digit OPE ID for institution

school_location_lon = [] # Longitude
school_location_lat = [] # Latitude

school_tuition_in_state = [] # In-state tuition and fees
school_tuition_out_of_state = [] # Out-of-state tuition and fees

# Loop through the Json file to append the data to the lists 
for data in school_data:
    school_open_admissions_policy.append(data['school.open_admissions_policy'])
    school_ownership_peps.append(data['school.ownership_peps'])
    school_price_calculator_url.append(data['school.price_calculator_url'])
    school_city.append(data['school.city'])
    school_ft_faculty_rate.append(data['school.ft_faculty_rate'])
    school_locale.append(data['school.locale'])
    school_accreditor.append(data['school.accreditor'])
    school_main_campus.append(data['school.main_campus'])
    school_alias.append(data['school.alias'])
    school_faculty_salary.append(data['school.faculty_salary'])
    school_state.append(data['school.state'])
    school_operating.append(data['school.operating'])
    school_instructional_expenditure_per_fte.append(data['school.instructional_expenditure_per_fte'])
    school_state_fips.append(data['school.state_fips'])
    school_zip.append(data['school.zip'])
    school_carnegie_undergrad.append(data['school.carnegie_undergrad'])
    school_women_only.append(data['school.women_only'])
    school_religious_affiliation.append(data['school.religious_affiliation'])
    school_tuition_revenue_per_fte.append(data['school.tuition_revenue_per_fte'])
    school_under_investigation.append(data['school.under_investigation'])
    school_region_id.append(data['school.region_id'])
    school_carnegie_basic.append(data['school.carnegie_basic'])
    school_branches.append(data['school.branches'])
    school_men_only.append(data['school.men_only'])
    school_school_url.append(data['school.school_url'])
    school_online_only.append(data['school.online_only'])
    school_ownership.append(data['school.ownership'])
    school_accreditor_code.append(data['school.accreditor_code'])
    school_name.append(data['school.name'])
    school_degree_urbanization.append(data['school.degree_urbanization'])
    school_carnegie_size_setting.append(data['school.carnegie_size_setting'])
    school_degrees_awarded_predominant.append(data['school.degrees_awarded.predominant'])
    school_degrees_awarded_highest.append(data['school.degrees_awarded.highest'])
    school_institutional_characteristics_level.append(data['school.institutional_characteristics.level'])
    school_title_iv_approval_date.append(data['school.title_iv.approval_date'])
    school_title_iv_eligibility_type.append(data['school.title_iv.eligibility_type'])
    school_id.append(data['id'])
    school_ope8_id.append(data['ope8_id'])
    school_ope6_id.append(data['ope6_id'])
    school_location_lon.append(data['location.lon'])
    school_location_lat.append(data['location.lat'])
    school_tuition_in_state.append(data['2017.cost.tuition.in_state'])
    school_tuition_out_of_state.append(data['2017.cost.tuition.out_of_state'])
    
# Update the dataframe with the information in the lists    
school_data_df['open_admissions_policy'] = school_open_admissions_policy
school_data_df['ownership_peps'] = school_ownership_peps
school_data_df['price_calculator_url'] = school_price_calculator_url
school_data_df['city'] = school_city
school_data_df['ft_faculty_rate'] = school_ft_faculty_rate
school_data_df['locale'] = school_locale
school_data_df['accreditor'] = school_accreditor
school_data_df['main_campus'] = school_main_campus
school_data_df['alias'] = school_alias
school_data_df['faculty_salary'] = school_faculty_salary
school_data_df['state'] = school_state
school_data_df['operating'] = school_operating
school_data_df['instructional_expenditure_per_fte'] = school_instructional_expenditure_per_fte
school_data_df['state_fips'] = school_state_fips
school_data_df['zip'] = school_zip
school_data_df['carnegie_undergrad'] = school_carnegie_undergrad
school_data_df['women_only'] = school_women_only
school_data_df['religious_affiliation'] = school_religious_affiliation
school_data_df['tuition_revenue_per_fte'] = school_tuition_revenue_per_fte
school_data_df['under_investigation'] = school_under_investigation
school_data_df['region_id'] = school_region_id
school_data_df['carnegie_basic'] = school_carnegie_basic
school_data_df['branches'] = school_branches
school_data_df['men_only'] = school_men_only
school_data_df['school_url'] = school_school_url
school_data_df['online_only'] = school_online_only
school_data_df['ownership'] = school_ownership
school_data_df['accreditor_code'] = school_accreditor_code
school_data_df['name'] = school_name
school_data_df['degree_urbanization'] = school_degree_urbanization
school_data_df['carnegie_size_setting'] = school_carnegie_size_setting

school_data_df['degrees_awarded_predominant'] = school_degrees_awarded_predominant
school_data_df['degrees_awarded_highest'] = school_degrees_awarded_highest
school_data_df['institutional_characteristics_level'] = school_institutional_characteristics_level
school_data_df['title_iv_approval_date'] = school_title_iv_approval_date
school_data_df['title_iv_eligibility_type'] = school_title_iv_eligibility_type

school_data_df['id'] = school_id
school_data_df['ope8_id'] = school_ope8_id
school_data_df['ope6_id'] = school_ope6_id

school_data_df['location_lon'] = school_location_lon
school_data_df['location_lat'] = school_location_lat

school_data_df['tuition_in_state'] = school_tuition_in_state
school_data_df['tuition_out_of_state'] = school_tuition_out_of_state



# Print the final dataframe
school_data_df.head()
# Out:
#    open_admissions_policy  ownership_peps  \
# 0                     1.0             3.0
# 1                     2.0             1.0
# 2                     2.0             1.0
# 3                     2.0             1.0
# 4                     2.0             2.0
#
#                                 price_calculator_url           city  \
# 0        westmichigancollegeofbarberingandbeauty.com      Kalamazoo
# 1                                 irout.gcsu.edu/cc/  Milledgeville
# 2  https://w3.georgiasouthern.edu/sta/fad/NetPric...     Statesboro
# 3  www.clayton.edu/Portals/20/netpricecalculator2...         Morrow
# 4  https://npc.collegeboard.org/student/app/andre...       Cuthbert
#
#    ft_faculty_rate  locale                                         accreditor  \
# 0              NaN      13  National Accrediting Commission of Career Arts...
# 1           0.8416      32  Southern Association of Colleges and Schools C...
# 2           0.9026      32  Southern Association of Colleges and Schools C...
# 3           0.6908      21  Southern Association of Colleges and Schools C...
# 4           0.8250      32  Southern Association of Colleges and Schools C...
#
#    main_campus            alias  faculty_salary  ... title_iv_approval_date  \
# 0            1             None             NaN  ...             12/12/1986
# 1            1  Georgia College          6958.0  ...              12/1/1965
# 2            1             None          6880.0  ...              12/1/1965
# 3            1             None          6680.0  ...               1/1/1966
# 4            1             None          4304.0  ...               5/1/1967
#
#    title_iv_eligibility_type      id   ope8_id ope6_id  location_lon  \
# 0                          1  152044  02491000  024910    -85.590244
# 1                          1  139861  00160200  001602    -83.231962
# 2                          1  139931  00157200  001572    -81.784045
# 3                          1  139311  00897600  008976    -84.328174
# 4                          1  138761  00154500  001545    -84.795021
#
#    location_lattuition_in_state  tuition_out_of_state  location_lat  \
# 0                           NaN                   NaN     42.259329
# 1                           NaN               28060.0     33.082787
# 2                           NaN               17142.0     32.426153
# 3                           NaN               15880.0     33.594079
# 4                           NaN               16560.0     31.772321
#
#    tuition_in_state
# 0               NaN
# 1            9346.0
# 2            6356.0
# 3            5419.0
# 4           16560.0
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Dataframe Columns Reorder & Division

# %% [markdown]
# All the dataframes are a slice of the main dataframe. This helps to upload them later in a database

# %% [markdown]
# ### Basic Dataframe

# %%
basic_df  = school_data_df[['id', 'ope8_id', 'ope6_id', 'name', 'alias', 
                            'city', 'state', 'state_fips', 'zip', 
                            'region_id', 'locale', 'school_url', ]]  
basic_df.head()
# Out:
#        id   ope8_id ope6_id                                           name  \
# 0  152044  02491000  024910  West Michigan College of Barbering and Beauty
# 1  139861  00160200  001602             Georgia College & State University
# 2  139931  00157200  001572                    Georgia Southern University
# 3  139311  00897600  008976                      Clayton  State University
# 4  138761  00154500  001545                                 Andrew College
#
#              alias           city state  state_fips         zip  region_id  \
# 0             None      Kalamazoo    MI          26       49008          3
# 1  Georgia College  Milledgeville    GA          13       31061          5
# 2             None     Statesboro    GA          13  30460-8126          5
# 3             None         Morrow    GA          13  30260-0285          5
# 4             None       Cuthbert    GA          13  39840-5550          5
#
#    locale                                   school_url
# 0      13  westmichigancollegeofbarberingandbeauty.com
# 1      32                                www.gcsu.edu/
# 2      32                      www.georgiasouthern.edu
# 3      21                              www.clayton.edu
# 4      32                        www.andrewcollege.edu

# %% [markdown]
# ### Detail Dataframe

# %%
detail_df  = school_data_df[['id', 'operating', 'under_investigation', 
                             'main_campus', 'branches', 'institutional_characteristics_level', 
                             'ownership_peps', 'ownership', 'online_only', 
                             'open_admissions_policy', ]]  
detail_df.head()
# Out:
#        id  operating  under_investigation  main_campus  branches  \
# 0  152044          1                    0            1         1
# 1  139861          1                    0            1         1
# 2  139931          1                    0            1         1
# 3  139311          1                    0            1         1
# 4  138761          1                    0            1         1
#
#    institutional_characteristics_level  ownership_peps  ownership  \
# 0                                    2               3          3
# 1                                    1               1          1
# 2                                    1               1          1
# 3                                    1               1          1
# 4                                    1               2          2
#
#    online_only  open_admissions_policy
# 0            0                       1
# 1            0                       2
# 2            0                       2
# 3            0                       2
# 4            0                       2

# %% [markdown]
# ### Metrics Dataframe

# %%
metrics_df  = school_data_df[['id', 'accreditor_code', 'accreditor', 
                              'degrees_awarded_predominant', 
                              'degrees_awarded_highest', 
                              'title_iv_approval_date', 
                              'title_iv_eligibility_type', 
                              'ft_faculty_rate', 'faculty_salary', 
                              'tuition_revenue_per_fte', 'price_calculator_url', 
                              'instructional_expenditure_per_fte', 
                              'degree_urbanization', 'carnegie_size_setting', 
                              'carnegie_undergrad', 'carnegie_basic', 
                              'men_only', 'women_only', 'religious_affiliation', 
                              'tuition_in_state', 'tuition_out_of_state', ]]  
metrics_df.head()
# Out:
#        id accreditor_code                                         accreditor  \
# 0  152044          NACCAS  National Accrediting Commission of Career Arts...
# 1  139861          SACSCC  Southern Association of Colleges and Schools C...
# 2  139931          SACSCC  Southern Association of Colleges and Schools C...
# 3  139311          SACSCC  Southern Association of Colleges and Schools C...
# 4  138761          SACSCC  Southern Association of Colleges and Schools C...
#
#    degrees_awarded_predominant  degrees_awarded_highest  \
# 0                            1                        1
# 1                            3                        4
# 2                            3                        4
# 3                            3                        4
# 4                            2                        2
#
#   title_iv_approval_date  title_iv_eligibility_type  ft_faculty_rate  \
# 0             12/12/1986                          1              NaN
# 1              12/1/1965                          1           0.8416
# 2              12/1/1965                          1           0.9026
# 3               1/1/1966                          1           0.6908
# 4               5/1/1967                          1           0.8250
#
#    faculty_salary  tuition_revenue_per_fte  ...  \
# 0             NaN                     5920  ...
# 1          6958.0                     8545  ...
# 2          6880.0                     6087  ...
# 3          6680.0                     5108  ...
# 4          4304.0                     7537  ...
#
#   instructional_expenditure_per_fte  degree_urbanization  \
# 0                              1628                 None
# 1                              6478                 None
# 2                              6408                 None
# 3                              5689                 None
# 4                              6953                 None
#
#   carnegie_size_setting  carnegie_undergrad  carnegie_basic  men_only  \
# 0                    -2                  -2              -2         0
# 1                    13                  14              18         0
# 2                    16                  15              16         0
# 3                    12                   9              19         0
# 4                     8                  11              14         0
#
#    women_only  religious_affiliation  tuition_in_state  tuition_out_of_state
# 0           0                    NaN               NaN                   NaN
# 1           0                    NaN            9346.0               28060.0
# 2           0                    NaN            6356.0               17142.0
# 3           0                    NaN            5419.0               15880.0
# 4           0                   71.0           16560.0               16560.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Geolocation Dataframe

# %%
geoloc_df  = school_data_df[['id', 'location_lon', 'location_lat', ]]  
geoloc_df.head()
# Out:
#        id  location_lon  location_lat
# 0  152044    -85.590244     42.259329
# 1  139861    -83.231962     33.082787
# 2  139931    -81.784045     32.426153
# 3  139311    -84.328174     33.594079
# 4  138761    -84.795021     31.772321

# %% [markdown]
# ## Import Auxiliar Dataframes from csv

# %% [markdown]
# ### Import from csv

# %%
state_fips_df = pd.read_csv('data/state_fips.csv')   # FIPS code for state
region_id_df = pd.read_csv('data/region_id.csv')   # Region (IPEDS)
locale_df = pd.read_csv('data/locale.csv')   # Locale of institution
operating_df = pd.read_csv('data/operating.csv')   # Flag for currently operating institution, 0=closed, 1=operating
under_investigation_df = pd.read_csv('data/under_investigation.csv')   # Schools that are on Heightened Cash Monitoring 2 by the Department of Education
main_campus_df = pd.read_csv('data/main_campus.csv')   # Flag for main campus
institutional_characteristics_level_df = pd.read_csv('data/institutional_characteristics_level.csv')   # Level of institution
ownership_peps_df = pd.read_csv('data/ownership_peps.csv')   # Control of institution, per PEPS
ownership_df = pd.read_csv('data/ownership.csv')   # Control of institution
online_only_df = pd.read_csv('data/online_only.csv')   # Flag for distance-education-only education
open_admissions_policy_df = pd.read_csv('data/open_admissions_policy.csv')   # Open admissions policy indicator
degrees_awarded_predominant_df = pd.read_csv('data/degrees_awarded_predominant.csv')   # Predominant undergraduate degree awarded
degrees_awarded_highest_df = pd.read_csv('data/degrees_awarded_highest.csv')   # Highest degree awarded
title_iv_eligibility_type_df = pd.read_csv('data/title_iv_eligibility_type.csv')   # Title IV eligibility type
carnegie_size_setting_df = pd.read_csv('data/carnegie_size_setting.csv')   # Carnegie Classification -- size and setting
carnegie_undergrad_df = pd.read_csv('data/carnegie_undergrad.csv')   # Carnegie Classification -- undergraduate profile
carnegie_basic_df = pd.read_csv('data/carnegie_basic.csv')   # Carnegie Classification -- basic
men_only_df = pd.read_csv('data/men_only.csv')   # Flag for men-only college
women_only_df = pd.read_csv('data/women_only.csv')   # Flag for women-only college
religious_affiliation_df = pd.read_csv('data/religious_affiliation.csv')   # Religous affiliation of the institution

# %% [markdown]
# ### Print the dataframes

# %%
print('state_fips: ', state_fips_df)
print('region_id: ', region_id_df)
print('locale: ', locale_df)
print('operating: ', operating_df)
print('under_investigation: ', under_investigation_df)
print('main_campus: ', main_campus_df)
print('institutional_characteristics_level: ', institutional_characteristics_level_df)
print('ownership_peps: ', ownership_peps_df)
print('ownership: ', ownership_df)
print('online_only: ', online_only_df)
print('open_admissions_policy: ', open_admissions_policy_df)
print('degrees_awarded_predominant: ', degrees_awarded_predominant_df)
print('degrees_awarded_highest: ', degrees_awarded_highest_df)
print('title_iv_eligibility_type: ', title_iv_eligibility_type_df)
print('carnegie_size_setting: ', carnegie_size_setting_df)
print('carnegie_undergrad: ', carnegie_undergrad_df)
print('carnegie_basic: ', carnegie_basic_df)
print('men_only: ', men_only_df)
print('women_only: ', women_only_df)
print('religious_affiliation: ', religious_affiliation_df)
# Out:
# state_fips:      code                     description
# 0      1                         Alabama
# 1      2                          Alaska
# 2      4                         Arizona
# 3      5                        Arkansas
# 4      6                      California
# 5      8                        Colorado
# 6      9                     Connecticut
# 7     10                        Delaware
# 8     11            District of Columbia
# 9     12                         Florida
# 10    13                         Georgia
# 11    15                          Hawaii
# 12    16                           Idaho
# 13    17                        Illinois
# 14    18                         Indiana
# 15    19                            Iowa
# 16    20                          Kansas
# 17    21                        Kentucky
# 18    22                       Louisiana
# 19    23                           Maine
# 20    24                        Maryland
# 21    25                   Massachusetts
# 22    26                        Michigan
# 23    27                       Minnesota
# 24    28                     Mississippi
# 25    29                        Missouri
# 26    30                         Montana
# 27    31                        Nebraska
# 28    32                          Nevada
# 29    33                   New Hampshire
# 30    34                      New Jersey
# 31    35                      New Mexico
# 32    36                        New York
# 33    37                  North Carolina
# 34    38                    North Dakota
# 35    39                            Ohio
# 36    40                        Oklahoma
# 37    41                          Oregon
# 38    42                    Pennsylvania
# 39    44                    Rhode Island
# 40    45                  South Carolina
# 41    46                    South Dakota
# 42    47                       Tennessee
# 43    48                           Texas
# 44    49                            Utah
# 45    50                         Vermont
# 46    51                        Virginia
# 47    53                      Washington
# 48    54                   West Virginia
# 49    55                       Wisconsin
# 50    56                         Wyoming
# 51    60                  American Samoa
# 52    64  Federated States of Micronesia
# 53    66                            Guam
# 54    69        Northern Mariana Islands
# 55    70                           Palau
# 56    72                     Puerto Rico
# 57    78                  Virgin Islands
# region_id:     code                                        description
# 0     0                               U.S. Service Schools
# 1     1               New England (CT, ME, MA, NH, RI, VT)
# 2     2                  Mid East (DE, DC, MD, NJ, NY, PA)
# 3     3                   Great Lakes (IL, IN, MI, OH, WI)
# 4     4                Plains (IA, KS, MN, MO, NE, ND, SD)
# 5     5  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 6     6                         Southwest (AZ, NM, OK, TX)
# 7     7               Rocky Mountains (CO, ID, MT, UT, WY)
# 8     8                  Far West (AK, CA, HI, NV, OR, WA)
# 9     9    Outlying Areas (AS, FM, GU, MH, MP, PR, PW, VI)
# locale:      code                                        description
# 0     11        City: Large (population of 250,000 or more)
# 1     12  City: Midsize (population of at least 100,000 ...
# 2     13         City: Small (population less than 100,000)
# 3     21  Suburb: Large (outside principal city, in urba...
# 4     22  Suburb: Midsize (outside principal city, in ur...
# 5     23  Suburb: Small (outside principal city, in urba...
# 6     31  Town: Fringe (in urban cluster up to 10 miles ...
# 7     32  Town: Distant (in urban cluster more than 10 m...
# 8     33  Town: Remote (in urban cluster more than 35 mi...
# 9     41  Rural: Fringe (rural territory up to 5 miles f...
# 10    42  Rural: Distant (rural territory more than 5 mi...
# 11    43  Rural: Remote (rural territory more than 25 mi...
# operating:     code                                        description
# 0     0  Not currently certified as an operating instit...
# 1     1                    Currently certified as operatin
# under_investigation:     code description
# 0     0          No
# 1     1        HCM2
# main_campus:     code      description
# 0     0  Not main campus
# 1     1      Main campus
# institutional_characteristics_level:     code       description
# 0     1            4-year
# 1     2            2-year
# 2     3  Less-than-2-year
# ownership_peps:     code         description
# 0     1  Public
# 1     2  Private, Nonprofit
# 2     3         Proprietary
# ownership:     code         description
# 0     1              Public
# 1     2   Private nonprofit
# 2     3  Private for-profit
# online_only:     code                  description
# 0     0  Not distance-education only
# 1     1      Distance-education only
# open_admissions_policy:     code                          description
# 0     1                                  Yes
# 1     2                                   No
# 2     3  Does not enroll first-time students
# degrees_awarded_predominant:     code                                description
# 0     0                             Not classified
# 1     1  Predominantly certificate-degree granting
# 2     2  Predominantly associate's-degree granting
# 3     3   Predominantly bachelor's-degree granting
# 4     4          Entirely graduate-degree granting
# degrees_awarded_highest:     code          description
# 0     0  Non-degree-granting
# 1     1   Certificate degree
# 2     2     Associate degree
# 3     3    Bachelor's degree
# 4     4      Graduate degree
# title_iv_eligibility_type:     code                                        description
# 0     1  Participates in Title IV federal financial aid...
# 1     2  Branch campus of a main campus that participat...
# 2     3             Deferment only - limited participation
# 3     5  Not currently participating in Title IV, has a...
# 4     6  Not currently participating in Title IV, does ...
# 5     7   Stopped participating during the collection year
# 6     8  New participants (became eligible during the c...
# carnegie_size_setting:      code                                      description
# 0     -2                                   Not applicable
# 1      0                                 (Not classified)
# 2      1                             Two-year, very small
# 3      2                                  Two-year, small
# 4      3                                 Two-year, medium
# 5      4                                  Two-year, large
# 6      5                             Two-year, very large
# 7      6  Four-year, very small, primarily nonresidential
# 8      7     Four-year, very small, primarily residential
# 9      8        Four-year, very small, highly residential
# 10     9       Four-year, small, primarily nonresidential
# 11    10          Four-year, small, primarily residential
# 12    11             Four-year, small, highly residential
# 13    12      Four-year, medium, primarily nonresidential
# 14    13         Four-year, medium, primarily residential
# 15    14            Four-year, medium, highly residential
# 16    15       Four-year, large, primarily nonresidential
# 17    16          Four-year, large, primarily residential
# 18    17             Four-year, large, highly residential
# 19    18                Exclusively graduate/professional
# carnegie_undergrad:      code                                        description
# 0     -2                                     Not applicable
# 1      0              Not classified (Exclusively Graduate)
# 2      1                         Two-year, higher part-time
# 3      2                     Two-year, mixed part/full-time
# 4      3                         Two-year, medium full-time
# 5      4                         Two-year, higher full-time
# 6      5                        Four-year, higher part-time
# 7      6  Four-year, medium full-time, inclusive, lower ...
# 8      7  Four-year, medium full-time, inclusive, higher...
# 9      8  Four-year, medium full-time, selective, lower ...
# 10     9  Four-year, medium full-time , selective, highe...
# 11    10  Four-year, full-time, inclusive, lower transfe...
# 12    11  Four-year, full-time, inclusive, higher transf...
# 13    12  Four-year, full-time, selective, lower transfe...
# 14    13  Four-year, full-time, selective, higher transf...
# 15    14  Four-year, full-time, more selective, lower tr...
# 16    15  Four-year, full-time, more selective, higher t...
# carnegie_basic:      code                                        description
# 0     -2                                     Not applicable
# 1      0                                   (Not classified)
# 2      1  Associate's Colleges: High Transfer-High Tradi...
# 3      2  Associate's Colleges: High Transfer-Mixed Trad...
# 4      3  Associate's Colleges: High Transfer-High Nontr...
# 5      4  Associate's Colleges: Mixed Transfer/Career & ...
# 6      5  Associate's Colleges: Mixed Transfer/Career & ...
# 7      6  Associate's Colleges: Mixed Transfer/Career & ...
# 8      7  Associate's Colleges: High Career & Technical-...
# 9      8  Associate's Colleges: High Career & Technical-...
# 10     9  Associate's Colleges: High Career & Technical-...
# 11    10         Special Focus Two-Year: Health Professions
# 12    11      Special Focus Two-Year: Technical Professions
# 13    12              Special Focus Two-Year: Arts & Design
# 14    13               Special Focus Two-Year: Other Fields
# 15    14  Baccalaureate/Associate's Colleges: Associate'...
# 16    15  Doctoral Universities: Very High Research Acti...
# 17    16      Doctoral Universities: High Research Activity
# 18    17                 Doctoral/Professional Universities
# 19    18  Master's Colleges & Universities: Larger Programs
# 20    19  Master's Colleges & Universities: Medium Programs
# 21    20   Master's Colleges & Universities: Small Programs
# 22    21      Baccalaureate Colleges: Arts & Sciences Focus
# 23    22             Baccalaureate Colleges: Diverse Fields
# 24    23  Baccalaureate/Associate's Colleges: Mixed Bacc...
# 25    24  Special Focus Four-Year: Faith-Related Institu...
# 26    25  Special Focus Four-Year: Medical Schools & Cen...
# 27    26  Special Focus Four-Year: Other Health Professi...
# 28    27       Special Focus Four-Year: Engineering Schools
# 29    28  Special Focus Four-Year: Other Technology-Rela...
# 30    29  Special Focus Four-Year: Business & Management...
# 31    30  Special Focus Four-Year: Arts, Music & Design ...
# 32    31               Special Focus Four-Year: Law Schools
# 33    32  Special Focus Four-Year: Other Special Focus I...
# 34    33                                    Tribal Colleges
# men_only:     code description
# 0     0          No
# 1     1         Yes
# women_only:     code description
# 0     0          No
# 1     1         Yes
# religious_affiliation:      code                              description
# 0     -1                             Not reported
# 1     -2                           Not applicable
# 2     22     American Evangelical Lutheran Church
# 3     24  African Methodist Episcopal Zion Church
# 4     27                 Assemblies of God Church
# ..   ...                                      ...
# 63   102                    Evangelical Christian
# 64   103                             Presbyterian
# 65   105                          General Baptist
# 66   106                                   Muslim
# 67   107                        Plymouth Brethren
#
# [68 rows x 2 columns]

# %%
print('The API was successfully queried and the information uploaded to Dataframes')
# Out:
# The API was successfully queried and the information uploaded to Dataframes
